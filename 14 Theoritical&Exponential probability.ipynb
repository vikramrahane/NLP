# %%
import numpy as np
from collections import Counter

# %%
#probability of head
p_head = 1/2

# Simulate 100 coins toss
tosses = [np.random.randint(0,2) for _ in range(100)]

#count the number of tosses 
p_heads = sum(tosses)

# calculate the experimental probability of heads
p_head_exp = heads/len(tosses)

print('theoritical probability of heads:',p_heads)
print('Exponental probability of heads:',p_head_exp)
# Out:
# theoritical probability of heads: 58
# Exponental probability of heads: 0.55

# %%
#Number of sides on the die
n_sides = 6

#Simulate 1000 die rolls
rolls = [np.random.randint(1,7) for _ in range(1000)]

# count the frequency of each outcome
counts = Counter(rolls)

#Calculate the Theoritical probability of rolling a 6
p_6 = 1/n_sides

# Calculate the experimental probability of rolling a 6
p_6_exp = counts[6]/len(rolls)

print('Theoritiacl  Probability of rolling a 6:',p_6)
print('Exponential Probability of rolling a 6:',p_6_exp)
# Out:
# Theoritiacl  Probability of rolling a 6: 0.16666666666666666
# Exponential Probability of rolling a 6: 0.171

# %%
x = np.arange(-5,5,0.25)

# %%
x
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])

# %%
y = x*3.47 + 12.056

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
x = np.arange(1,10,0.25)

# %%
y = np.log(x)

# %%
plt.plot(x,y)

# %%
x = np.arange(-5,5,0.25)

# %%
y = x**2 + 12.056

# %%
plt.plot(x,y)

# %%
x = np.arange(-5,5,0.25)

# %%
y = x**2 + 12.056

# %%
def sigmoid(z):
    val = 1/(1+np.exp(-z))
    return val

# %%
plt.plot(sigmoid(x))

# %%
import random
#define states 
states = ['Sunny','Rainy']

# Define Transition matrix
transition_matrix = [
    [0.7,0.3],
    [0.8,0.2]
]

# define initial state
initial_state = 'Sunny'

# %%
#Number of steps to simulate
num_steps= 20

#Generate weather sequence 
weather_sequence = [initial_state]
for i in range(num_steps):
    current_state = weather_sequence[-1]
    next_state_index = random.choices(
        range(len(states)),
        weights = transition_matrix[states.index(current_state)])[0]
    next_state = states[next_state_index]
    weather_sequence.append(next_state)
    
#print the generated weather sequence 
print('weather sequence: ',weather_sequence)
# Out:
# weather sequence:  ['Sunny', 'Rainy', 'Sunny', 'Rainy', 'Sunny', 'Sunny', 'Sunny', 'Sunny', 'Sunny', 'Rainy', 'Sunny', 'Rainy', 'Sunny', 'Sunny', 'Rainy', 'Sunny', 'Rainy', 'Rainy', 'Sunny', 'Sunny', 'Sunny']
