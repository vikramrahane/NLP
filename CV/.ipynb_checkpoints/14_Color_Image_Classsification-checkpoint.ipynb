# %%
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import to_categorical

# %%
(x_train,y_train),(x_test,y_test)= cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
plt.imshow(x_train[3])

# %%
y_train[1]
# Out:
# array([9], dtype=uint8)

# %%
labels = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %% [markdown]
# ### Explore the data

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.imshow(x_train[i])
  plt.xticks([]); plt.yticks([])
  plt.title(labels[y_train[i][0]])

# %%
x_train = x_train/255
x_test = x_test/255

# %% [markdown]
# ## Build the model

# %%
model= Sequential()

model.add(Conv2D(filters=32, input_shape=(32,32,3), activation='relu', kernel_size=(3,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters=16, activation='relu', kernel_size=(3,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(256, activation='relu'))

model.add(Dense(10, activation='softmax'))

# %% [markdown]
# ## Compile the model

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Train the model

# %%
model.fit(x_train, y_train, batch_size=10, epochs=10)
# Out:
# Epoch 1/10
# 5000/5000 [==============================] - 24s 4ms/step - loss: 1.4108 - accuracy: 0.4922
# Epoch 2/10
# 5000/5000 [==============================] - 24s 5ms/step - loss: 1.0791 - accuracy: 0.6212
# Epoch 3/10
# 5000/5000 [==============================] - 32s 6ms/step - loss: 0.9312 - accuracy: 0.6750
# Epoch 4/10
# 5000/5000 [==============================] - 19s 4ms/step - loss: 0.8198 - accuracy: 0.7138
# Epoch 5/10
# 5000/5000 [==============================] - 20s 4ms/step - loss: 0.7342 - accuracy: 0.7450
# Epoch 6/10
# 5000/5000 [==============================] - 19s 4ms/step - loss: 0.6543 - accuracy: 0.7716
# Epoch 7/10
# 5000/5000 [==============================] - 19s 4ms/step - loss: 0.5875 - accuracy: 0.7930
# Epoch 8/10
# 5000/5000 [==============================] - 20s 4ms/step - loss: 0.5238 - accuracy: 0.8159
# Epoch 9/10
# 5000/5000 [==============================] - 21s 4ms/step - loss: 0.4703 - accuracy: 0.8334
# Epoch 10/10
# 5000/5000 [==============================] - 19s 4ms/step - loss: 0.4213 - accuracy: 0.8520

# %% [markdown]
# ## Evaluate the model

# %%
model.evaluate(x_test, y_test, batch_size=1)
# Out:
# 10000/10000 [==============================] - 26s 3ms/step - loss: 1.2385 - accuracy: 0.6652
# [1.2385411262512207, 0.6651999950408936]

# %%
img = x_test[578]
img = img.reshape(32,32,3)

# %%
plt.imshow(img,cmap='gray');

# %%
new = img.reshape(1,32,32,3)
a=np.argmax(model.predict(new))
print(labels[a])
# Out:
# 1/1 [==============================] - 0s 87ms/step
# horse

# %%
new_img = plt.imread('deer1.jpg')

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (1, 32, 32, 3)

# %%
new_img = new_img/255
new_img = new_img.reshape(1,32,32,3)
a=np.argmax(model.predict(new_img,verbose=0))
print(labels[a])
# Out:
# dog
